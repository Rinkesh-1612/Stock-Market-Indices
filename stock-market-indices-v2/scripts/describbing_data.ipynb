# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/final/final_all_historical_prices_parquet.parquet")
df.describe(include='all')
# Out:
#               Date    000001.SS    000016.SS      0001.HK      0002.HK  \
# count         2613  2429.000000     1.000000  2464.000000  2464.000000
# unique        2613          NaN          NaN          NaN          NaN
# top     2025-11-04          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN  3175.988689  3012.968994    49.808930    58.943162
# std            NaN   273.500285          NaN    10.690727     6.136764
# min            NaN  2464.363037  3012.968994    31.946815    41.535061
# 25%            NaN  2979.125977  3012.968994    40.604053    55.150864
# 50%            NaN  3184.979980  3012.968994    47.551210    59.440666
# 75%            NaN  3364.649902  3012.968994    59.854810    63.887542
# max            NaN  4016.331055  3012.968994    72.983292    71.836044
#
#             0003.HK    000300.SS      0005.HK      0006.HK      0011.HK  ...  \
# ...

# %%
df = pd.read_csv("../data/final/data_cleaned/constituent_verification_summary.csv")
df.describe(include='all')
# Out:
#                 Index Name    Raw Count  Verified Count Success Rate
# count                   71    71.000000       71.000000           71
# unique                  71          NaN             NaN           22
# top     Russell 2000 Index          NaN             NaN            0
# freq                     1          NaN             NaN           33
# mean                   NaN    84.464789       68.211268          NaN
# std                    NaN   267.311740      262.980766          NaN
# min                    NaN     0.000000        0.000000          NaN
# 25%                    NaN     0.000000        0.000000          NaN
# 50%                    NaN    18.000000        0.000000          NaN
# 75%                    NaN    50.000000       32.000000          NaN
# max                    NaN  1970.000000     1950.000000          NaN

# %%
df1 = pd.read_csv("../data/final/final_company_info_usd.csv")
df1.describe(include='all')
# Out:
#        Company Ticker              Sector          Industry     MarketCap  \
# count            3833                3833              3833  3.833000e+03
# unique           3833                  11               143           NaN
# top              ZYME  Financial Services  Banks - Regional           NaN
# freq                1                 657               327           NaN
# mean              NaN                 NaN               NaN  9.298390e+10
# std               NaN                 NaN               NaN  6.671614e+11
# min               NaN                 NaN               NaN  1.464957e+07
# 25%               NaN                 NaN               NaN  8.729140e+08
# 50%               NaN                 NaN               NaN  3.647448e+09
# 75%               NaN                 NaN               NaN  1.537718e+10
# max               NaN                 NaN               NaN  1.995751e+13
#
#        Currency  MarketCap_USD
# count      3833   3.833000e+03
# ...

# %%
df1 = pd.read_csv("../data/final/data_cleaned/_DJU.csv")
df1.describe(include='all')
# Out:
#                    Company Name Company Ticker
# count                        15             15
# unique                       15             15
# top     American Electric Power            AEP
# freq                          1              1

# %%
df1 = pd.read_csv("../data/final/data_cleaned/master_indices_list.csv")
df1.describe(include='all')
# Out:
#                              Index Name Ticker        Country      Continent  \
# count                                71     71             71             71
# unique                               71     71             32              6
# top     Dow Jones Global Titans 50 Inde  ^DJGT  United States  North America
# freq                                  1      1             21             23
# mean                                NaN    NaN            NaN            NaN
# std                                 NaN    NaN            NaN            NaN
# min                                 NaN    NaN            NaN            NaN
# 25%                                 NaN    NaN            NaN            NaN
# 50%                                 NaN    NaN            NaN            NaN
# 75%                                 NaN    NaN            NaN            NaN
# max                                 NaN    NaN            NaN            NaN
#
#          Latitude   Longitude
# ...

# %%
df1 = pd.read_csv("../data/final/master_constituents_list.csv")
df1.describe(include='all')
# Out:
#                  Index Name Company Name Company Ticker
# count                  4843         4843           4843
# unique                   34         4083           3980
# top      Russell 2000 Index          IBM            IBM
# freq                   1950            7              7
