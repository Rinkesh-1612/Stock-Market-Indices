# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import datetime
import logging
import os
import io

# --- Configuration ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# --- USER-EDITABLE PATH VARIABLE ---
# Define the output directory for the CSV files.
CUSTOM_OUTPUT_DIR = r"/content/output2"  # <-- EDIT THIS LINE TO YOUR DESIRED PATH

# --- Index Scraping Configurations ---
# This dictionary holds all the information needed to scrape constituent tickers for each index.
INDEX_CONFIG = {
    "sp500": {
        "name": "S&P 500",
        "url": "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies",
        "table_identifier": {'id': 'constituents'},
        "ticker_column": "Symbol",
        "name_column": "Security", # Added name column
        "clean_fn": lambda s: s.replace('.', '-')  # For tickers like 'BRK.B' -> 'BRK-B'
    },
    "dowjones": {
        "name": "Dow Jones",
        "url": "https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average",
        "table_identifier": {'id': 'constituents'},
        "ticker_column": "Symbol",
        "name_column": "Company", # Added name column
        "clean_fn": lambda s: s
    },
    "nasdaq100": {
        "name": "NASDAQ 100",
        "url": "https://en.wikipedia.org/wiki/Nasdaq-100",
        "table_identifier": {'id': 'constituents'},
        "ticker_column": "Ticker",
        "name_column": "Company", # Added name column
        "clean_fn": lambda s: s.replace('.', '-')
    },
    "nifty50": {
        "name": "Nifty 50",
        "url": "https://en.wikipedia.org/wiki/NIFTY_50",
        "table_identifier": {'id': 'constituents'},
        "ticker_column": "Symbol",
        "name_column": "Company name", # Corrected name column
        "clean_fn": lambda s: f"{s}.NS"  # Append .NS for National Stock Exchange of India
    },
    "ftse100": {
        "name": "FTSE 100",
        "url": "https://en.wikipedia.org/wiki/FTSE_100_Index",
        "table_identifier": {'id': 'constituents'},
        "ticker_column": "Ticker",  # Changed to Ticker
        "name_column": "Company", # Added name column
        "clean_fn": lambda s: f"{s}.L" if '.' not in s else s # Append .L for London Stock Exchange
    }
}

def get_tickers_from_wikipedia(config):
    """Scrapes tickers and company names from a Wikipedia page based on a flexible configuration."""
    name = config['name']
    url = config['url']
    table_id = config['table_identifier']
    ticker_col = config['ticker_column']
    name_col = config['name_column'] # Get name column
    logging.info(f"--- Scraping ticker list for {name} ---")
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
        response = requests.get(url, headers=headers, timeout=15)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'lxml')
        table = soup.find('table', table_id)
        if table is None:
            logging.error(f"Could not find specified table on {url} for {name}.")
            return [], {}

        df = pd.read_html(io.StringIO(str(table)))[0]

        if ticker_col not in df.columns:
            logging.error(f"Ticker column '{ticker_col}' not found in {name} table. Available columns: {df.columns.tolist()}")
            return [], {}

        if name_col not in df.columns: # Check for name column
            logging.error(f"Name column '{name_col}' not found in {name} table. Available columns: {df.columns.tolist()}")
            return [], {}

        # Create a dictionary mapping cleaned tickers to company names
        ticker_name_map = dict(zip(df[ticker_col].astype(str).apply(config['clean_fn']), df[name_col].astype(str)))

        tickers = list(ticker_name_map.keys())

        logging.info(f"[SUCCESS] Fetched {len(tickers)} tickers for {name}. First 5: {tickers[:5]}")
        return tickers, ticker_name_map

    except Exception as e:
        logging.error(f"Scraping tickers for {name} failed: {e}")
        return [], {}

def fetch_and_save_closing_prices(index_name, tickers, ticker_name_map, output_dir):
    """
    Fetches daily closing prices and volume for a list of tickers in a single batch call
    and saves the result as a CSV with company names as headers.
    """
    if not tickers:
        logging.warning(f"[SKIP] No tickers provided for {index_name}.")
        return

    logging.info(f"=== Starting data fetch for {index_name} ({len(tickers)} stocks) ===")

    end_date = datetime.date.today()
    start_date = end_date - datetime.timedelta(days=3*365) # Fetch 3 years of data

    try:
        all_data = yf.download(tickers, start=start_date, end=end_date, progress=True)

        if all_data.empty:
            logging.error(f"No data returned for any tickers in {index_name}.")
            return

        # Use pd.concat for more efficient DataFrame creation
        data_frames = []
        for ticker in tickers:
            if ticker in all_data['Close'].columns: # Check if ticker data was fetched
                company_name = ticker_name_map.get(ticker, ticker) # Use company name or ticker if not found
                temp_df = pd.DataFrame(index=all_data.index)
                temp_df[(company_name, 'Close')] = all_data['Close'][ticker]
                if ticker in all_data['Volume'].columns: # Check if volume data exists
                    temp_df[(company_name, 'Volume')] = all_data['Volume'][ticker]
                else:
                    temp_df[(company_name, 'Volume')] = None # Add empty volume column if not available
                data_frames.append(temp_df)

        if not data_frames:
            logging.error(f"No valid ticker data to combine for {index_name}.")
            return

        combined_df = pd.concat(data_frames, axis=1)

        combined_df.index.name = 'Date'
        logging.info(f"Finished fetching data for {index_name}.")
        logging.info(f"  Result shape: dates={combined_df.shape[0]}, successfully fetched stocks={combined_df.shape[1]//2}") # Divide by 2 for Close/Volume pairs
        logging.info(f"  Sample Head:\n{combined_df.head(2)}")

        # Save DataFrame as CSV
        os.makedirs(output_dir, exist_ok=True)
        filename = os.path.join(output_dir, f"{index_name.replace(' ', '_')}_stock_data.csv")
        # Flatten the multi-level columns for CSV output
        combined_df.columns = ['_'.join(col).strip() for col in combined_df.columns.values]
        combined_df.to_csv(filename)
        logging.info(f"[SAVED] Data saved to {filename}\n")

    except Exception as e:
        logging.error(f"An error occurred during data download for {index_name}: {e}")

if __name__ == "__main__":
    indices_to_process = ["sp500", "dowjones", "nasdaq100", "nifty50", "ftse100"]

    # Ensure the main output directory exists
    os.makedirs(CUSTOM_OUTPUT_DIR, exist_ok=True)

    for index_key in indices_to_process:
        config = INDEX_CONFIG[index_key]
        tickers, ticker_name_map = get_tickers_from_wikipedia(config)
        fetch_and_save_closing_prices(config['name'], tickers, ticker_name_map, CUSTOM_OUTPUT_DIR)

    logging.info("=== ALL PROCESSES COMPLETE ===")
# Out:
# 2025-10-29 17:02:46,161 - INFO - --- Scraping ticker list for S&P 500 ---
# 2025-10-29 17:02:46,892 - INFO - [SUCCESS] Fetched 503 tickers for S&P 500. First 5: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN']
# 2025-10-29 17:02:46,894 - INFO - === Starting data fetch for S&P 500 (503 stocks) ===
# YF.download() has changed argument auto_adjust default to True
# 2025-10-29 17:02:51,270 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:02:51,273 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*                      2%                       ]  10 of 503 completed2025-10-29 17:02:53,708 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*                      2%                       ]  11 of 503 completed2025-10-29 17:02:53,727 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**                     4%                       ]  18 of 503 completed2025-10-29 17:02:54,517 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**                     4%                       ]  19 of 503 completed2025-10-29 17:02:54,532 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**                     5%                       ]  23 of 503 completed2025-10-29 17:02:56,039 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:02:56,053 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***                    6%                       ]  31 of 503 completed2025-10-29 17:02:57,241 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***                    6%                       ]  32 of 503 completed2025-10-29 17:02:57,247 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***                    7%                       ]  34 of 503 completed2025-10-29 17:02:58,741 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:02:58,747 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****                   8%                       ]  41 of 503 completed2025-10-29 17:03:00,143 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****                   8%                       ]  42 of 503 completed2025-10-29 17:03:00,149 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****                   9%                       ]  45 of 503 completed2025-10-29 17:03:01,195 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****                   9%                       ]  46 of 503 completed2025-10-29 17:03:01,213 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*****                 11%                       ]  54 of 503 completed2025-10-29 17:03:03,195 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:03,198 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******                12%                       ]  59 of 503 completed2025-10-29 17:03:04,413 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:04,415 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******                13%                       ]  66 of 503 completed2025-10-29 17:03:06,073 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******                13%                       ]  67 of 503 completed2025-10-29 17:03:06,081 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******               14%                       ]  71 of 503 completed2025-10-29 17:03:07,407 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:07,410 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********              16%                       ]  79 of 503 completed2025-10-29 17:03:08,783 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********              16%                       ]  80 of 503 completed2025-10-29 17:03:08,796 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********              17%                       ]  83 of 503 completed2025-10-29 17:03:10,651 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:10,662 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********             18%                       ]  91 of 503 completed2025-10-29 17:03:12,138 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********             18%                       ]  92 of 503 completed2025-10-29 17:03:12,177 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********             19%                       ]  94 of 503 completed2025-10-29 17:03:13,457 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:13,505 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********            20%                       ]  100 of 503 completed2025-10-29 17:03:14,741 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********            21%                       ]  104 of 503 completed2025-10-29 17:03:14,755 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********            21%                       ]  106 of 503 completed2025-10-29 17:03:16,281 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********            21%                       ]  107 of 503 completed2025-10-29 17:03:16,288 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***********           23%                       ]  116 of 503 completed2025-10-29 17:03:17,766 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:17,767 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***********           23%                       ]  118 of 503 completed2025-10-29 17:03:19,716 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:19,724 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [************          25%                       ]  127 of 503 completed2025-10-29 17:03:21,546 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [************          25%                       ]  128 of 503 completed2025-10-29 17:03:21,584 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [************          26%                       ]  130 of 503 completed2025-10-29 17:03:23,127 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [************          26%                       ]  131 of 503 completed2025-10-29 17:03:23,134 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*************         28%                       ]  139 of 503 completed2025-10-29 17:03:24,494 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*************         28%                       ]  140 of 503 completed2025-10-29 17:03:24,499 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*************         28%                       ]  142 of 503 completed2025-10-29 17:03:25,624 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:25,647 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**************        30%                       ]  151 of 503 completed2025-10-29 17:03:26,933 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**************        30%                       ]  152 of 503 completed2025-10-29 17:03:26,937 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***************       31%                       ]  155 of 503 completed2025-10-29 17:03:28,706 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:28,715 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***************       32%                       ]  160 of 503 completed2025-10-29 17:03:30,795 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***************       32%                       ]  163 of 503 completed2025-10-29 17:03:30,856 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****************      33%                       ]  167 of 503 completed2025-10-29 17:03:32,590 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:32,664 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*****************     35%                       ]  176 of 503 completed2025-10-29 17:03:34,440 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:34,444 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*****************     35%                       ]  178 of 503 completed2025-10-29 17:03:35,923 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:35,925 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******************    37%                       ]  185 of 503 completed2025-10-29 17:03:37,494 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:37,496 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******************    38%                       ]  190 of 503 completed2025-10-29 17:03:39,094 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******************    38%                       ]  192 of 503 completed2025-10-29 17:03:39,102 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******************   40%                       ]  199 of 503 completed2025-10-29 17:03:40,939 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******************   40%                       ]  200 of 503 completed2025-10-29 17:03:41,069 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******************   40%                       ]  203 of 503 completed2025-10-29 17:03:42,435 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:42,437 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********************  41%                       ]  208 of 503 completed2025-10-29 17:03:43,908 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********************  42%                       ]  212 of 503 completed2025-10-29 17:03:43,922 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********************* 43%                       ]  216 of 503 completed2025-10-29 17:03:46,144 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:46,148 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************45%                       ]  224 of 503 completed2025-10-29 17:03:47,662 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************45%                       ]  225 of 503 completed2025-10-29 17:03:47,675 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************45%                       ]  228 of 503 completed2025-10-29 17:03:49,144 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:49,183 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************47%                       ]  235 of 503 completed2025-10-29 17:03:51,331 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:51,334 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************48%                       ]  240 of 503 completed2025-10-29 17:03:53,141 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:53,144 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************49%                       ]  247 of 503 completed2025-10-29 17:03:54,388 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************49%                       ]  248 of 503 completed2025-10-29 17:03:54,417 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************50%                       ]  252 of 503 completed2025-10-29 17:03:55,443 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:55,446 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************51%                       ]  259 of 503 completed2025-10-29 17:03:56,870 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************52%                       ]  260 of 503 completed2025-10-29 17:03:56,941 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************52%                       ]  264 of 503 completed2025-10-29 17:03:58,479 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:03:58,484 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************54%*                      ]  273 of 503 completed2025-10-29 17:04:00,044 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:00,055 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************55%*                      ]  275 of 503 completed2025-10-29 17:04:01,597 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************55%*                      ]  276 of 503 completed2025-10-29 17:04:01,616 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************56%**                     ]  283 of 503 completed2025-10-29 17:04:03,134 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:03,136 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************57%**                     ]  288 of 503 completed2025-10-29 17:04:05,110 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:05,124 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************58%***                    ]  294 of 503 completed2025-10-29 17:04:06,178 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************59%***                    ]  296 of 503 completed2025-10-29 17:04:06,184 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************59%***                    ]  299 of 503 completed2025-10-29 17:04:08,213 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************60%****                   ]  300 of 503 completed2025-10-29 17:04:08,367 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************61%****                   ]  308 of 503 completed2025-10-29 17:04:09,501 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************61%****                   ]  309 of 503 completed2025-10-29 17:04:09,510 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************62%*****                  ]  310 of 503 completed2025-10-29 17:04:11,269 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************62%*****                  ]  311 of 503 completed2025-10-29 17:04:11,296 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************63%*****                  ]  319 of 503 completed2025-10-29 17:04:12,507 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************64%******                 ]  320 of 503 completed2025-10-29 17:04:12,619 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************64%******                 ]  322 of 503 completed2025-10-29 17:04:13,812 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************64%******                 ]  323 of 503 completed2025-10-29 17:04:13,819 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************65%******                 ]  329 of 503 completed2025-10-29 17:04:15,349 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************66%*******                ]  332 of 503 completed2025-10-29 17:04:15,351 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************68%********               ]  342 of 503 completed2025-10-29 17:04:16,855 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:17,271 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************70%*********              ]  351 of 503 completed2025-10-29 17:04:17,805 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************70%*********              ]  352 of 503 completed2025-10-29 17:04:17,830 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************70%*********              ]  354 of 503 completed2025-10-29 17:04:19,359 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************71%*********              ]  355 of 503 completed2025-10-29 17:04:19,365 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************72%**********             ]  363 of 503 completed2025-10-29 17:04:20,609 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:20,616 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************73%**********             ]  366 of 503 completed2025-10-29 17:04:21,842 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************73%**********             ]  367 of 503 completed2025-10-29 17:04:21,864 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************74%***********            ]  374 of 503 completed2025-10-29 17:04:23,100 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************75%***********            ]  375 of 503 completed2025-10-29 17:04:23,143 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************75%***********            ]  379 of 503 completed2025-10-29 17:04:24,267 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:24,372 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************77%************           ]  386 of 503 completed2025-10-29 17:04:25,739 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************77%************           ]  387 of 503 completed2025-10-29 17:04:25,743 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************82%**************         ]  410 of 503 completed2025-10-29 17:04:34,554 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************82%**************         ]  411 of 503 completed2025-10-29 17:04:34,617 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************83%***************        ]  415 of 503 completed2025-10-29 17:04:35,703 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************83%***************        ]  416 of 503 completed2025-10-29 17:04:36,233 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************84%***************        ]  422 of 503 completed2025-10-29 17:04:36,790 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************84%***************        ]  423 of 503 completed2025-10-29 17:04:37,335 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************86%****************       ]  431 of 503 completed2025-10-29 17:04:38,140 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************86%****************       ]  432 of 503 completed2025-10-29 17:04:38,173 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************87%*****************      ]  438 of 503 completed2025-10-29 17:04:39,307 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************87%*****************      ]  439 of 503 completed2025-10-29 17:04:39,318 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************88%*****************      ]  443 of 503 completed2025-10-29 17:04:40,614 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:40,708 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************89%******************     ]  450 of 503 completed2025-10-29 17:04:41,830 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:41,832 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************91%*******************    ]  456 of 503 completed2025-10-29 17:04:43,500 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:43,503 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************92%*******************    ]  462 of 503 completed2025-10-29 17:04:45,567 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:45,616 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************93%********************   ]  468 of 503 completed2025-10-29 17:04:46,964 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************93%********************   ]  469 of 503 completed2025-10-29 17:04:47,005 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************94%********************   ]  474 of 503 completed2025-10-29 17:04:48,086 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:48,089 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************95%*********************  ]  480 of 503 completed2025-10-29 17:04:49,184 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:49,194 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************97%********************** ]  486 of 503 completed2025-10-29 17:04:50,676 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:50,739 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************98%********************** ]  492 of 503 completed2025-10-29 17:04:52,121 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:52,132 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********************100%***********************]  502 of 503 completed
# 2025-10-29 17:04:55,029 - ERROR -
# 503 Failed downloads:
# 2025-10-29 17:04:55,031 - ERROR - ['KEYS', 'PWR', 'CTRA', 'BMY', 'VMC', 'ELV', 'HSY', 'IP', 'CVS', 'HBAN', 'SJM', 'KMX', 'BXP', 'LIN', 'FAST', 'CNC', 'WELL', 'OXY', 'UHS', 'MTD', 'DHR', 'POOL', 'MSCI', 'TAP', 'AEP', 'CAT', 'ATO', 'MDT', 'TGT', 'HAL', 'VST', 'V', 'AVGO', 'BLDR', 'ZTS', 'DD', 'AEE', 'ROL', 'MLM', 'GEN', 'PH', 'TDG', 'HOOD', 'ORLY', 'PEG', 'KLAC', 'LMT', 'ARE', 'IVZ', 'IQV', 'TER', 'BAC', 'FE', 'SOLV', 'AZO', 'IBM', 'TDY', 'UBER', 'ITW', 'NWSA', 'APTV', 'PKG', 'LOW', 'ECL', 'MHK', 'ESS', 'WDAY', 'HUM', 'GIS', 'KR', 'WMB', 'VLO', 'LDOS', 'HPE', 'PRU', 'AES', 'NOC', 'CAG', 'AIG', 'META', 'MGM', 'IBKR', 'IPG', 'FDX', 'AJG', 'ES', 'DVN', 'MSI', 'GS', 'AMZN', 'T', 'ADSK', 'DHI', 'CFG', 'STLD', 'INVH', 'EXPE', 'ICE', 'GRMN', 'AMAT', 'AME', 'NTAP', 'JPM', 'MAA', 'FOXA', 'EA', 'AOS', 'JKHY', 'GPN', 'ABT', 'ACN', 'NRG', 'SPG', 'LYV', 'BF-B', 'SYK', 'ROST', 'TYL', 'INCY', 'BEN', 'ALL', 'ABNB', 'LEN', 'DUK', 'BRK-B', 'CBRE', 'CB', 'AIZ', 'JCI', 'AAPL', 'BBY', 'PFE', 'GOOGL', 'CTVA', 'IDXX', 'FTNT', 'PSKY', 'RF', 'DPZ', 'PHM', 'ETR', 'MSFT', 'REGN', 'VTR', 'APO', 'CCI', 'SCHW', 'MKC', 'CF', 'HPQ', 'AMCR', 'D', 'KMB', 'TPL', 'FANG', 'CMCSA', 'MCO', 'DASH', 'FFIV', 'RTX', 'TPR', 'STZ', 'SHW', 'ISRG', 'CCL', 'ULTA', 'TKO', 'IR', 'REG', 'BALL', 'RL', 'HD', 'INTC', 'VRSK', 'RMD', 'SYF', 'DVA', 'CBOE', 'SYY', 'KHC', 'PODD', 'INTU', 'MCD', 'JBL', 'WAT', 'DECK', 'FCX', 'SO', 'MCK', 'HII', 'FDS', 'CVX', 'AVY', 'MAS', 'APH', 'A', 'AMT', 'GDDY', 'EVRG', 'PANW', 'FI', 'ODFL', 'COIN', 'TRMB', 'MS', 'ETN', 'GLW', 'HUBB', 'ANET', 'ORCL', 'WY', 'NVDA', 'COR', 'MRK', 'WRB', 'CNP', 'NUE', 'CAH', 'WEC', 'DAY', 'DE', 'ADBE', 'MU', 'RJF', 'TTD', 'DOC', 'CTAS', 'ADI', 'BK', 'BKR', 'WSM', 'WDC', 'DLTR', 'BA', 'AKAM', 'DGX', 'CARR', 'OMC', 'EW', 'TECH', 'CPAY', 'SNPS', 'HSIC', 'DTE', 'NDSN', 'L', 'ALLE', 'UNH', 'CSGP', 'TRGP', 'AVB', 'LH', 'HWM', 'UPS', 'SRE', 'MA', 'O', 'FITB', 'LII', 'NDAQ', 'JBHT', 'F', 'BIIB', 'HIG', 'XOM', 'MPWR', 'VICI', 'ALGN', 'AXP', 'HAS', 'PCAR', 'BRO', 'ADM', 'BR', 'LYB', 'DIS', 'KDP', 'KKR', 'BG', 'IT', 'WYNN', 'BLK', 'PCG', 'VLTO', 'EQT', 'MNST', 'KVUE', 'CTSH', 'HCA', 'UDR', 'KMI', 'MET', 'AWK', 'COF', 'CHTR', 'NEE', 'ACGL', 'LNT', 'PNC', 'DELL', 'BX', 'LHX', 'IEX', 'PAYX', 'GPC', 'PPL', 'PAYC', 'AON', 'LVS', 'BDX', 'ALB', 'DLR', 'STT', 'TMO', 'MPC', 'HRL', 'FOX', 'EXE', 'GE', 'STX', 'LKQ', 'PLD', 'STE', 'CLX', 'PYPL', 'TSN', 'PNR', 'CPT', 'APD', 'CHD', 'NTRS', 'TSCO', 'SW', 'GL', 'COO', 'EL', 'QCOM', 'TROW', 'AMD', 'FICO', 'WAB', 'HON', 'HST', 'WFC', 'AMGN', 'AFL', 'DOW', 'TTWO', 'ADP', 'XYZ', 'TRV', 'UAL', 'KIM', 'MOS', 'MDLZ', 'WM', 'ZBRA', 'EPAM', 'NKE', 'GEHC', 'CME', 'HLT', 'PEP', 'UNP', 'CRM', 'TXT', 'DOV', 'ZBH', 'SMCI', 'SBAC', 'PNW', 'CPRT', 'CMG', 'CDW', 'SWK', 'DDOG', 'RVTY', 'CL', 'TXN', 'APP', 'K', 'NVR', 'MRNA', 'EXC', 'GEV', 'C', 'EBAY', 'PG', 'GM', 'NSC', 'MOH', 'CMI', 'MTB', 'DAL', 'PSA', 'MO', 'WTW', 'GILD', 'PLTR', 'NWS', 'SWKS', 'WST', 'SPGI', 'NI', 'GD', 'WMT', 'EXPD', 'LRCX', 'TT', 'FSLR', 'MMC', 'IFF', 'EQR', 'CSCO', 'EME', 'MCHP', 'GOOG', 'LW', 'MMM', 'LULU', 'CSX', 'SLB', 'TEL', 'PSX', 'CPB', 'CRL', 'TJX', 'ED', 'J', 'DG', 'TSLA', 'MTCH', 'PPG', 'AXON', 'CRWD', 'EMN', 'CHRW', 'PGR', 'CMS', 'EOG', 'XEL', 'WBD', 'YUM', 'NCLH', 'IRM', 'PFG', 'CEG', 'HOLX', 'FIS', 'JNJ', 'PTC', 'SNA', 'AMP', 'ON', 'ABBV', 'EQIX', 'ROK', 'COP', 'NXPI', 'OKE', 'GWW', 'EFX', 'DXCM', 'VTRS', 'APA', 'RCL', 'EXR', 'FRT', 'LUV', 'BAX', 'URI', 'CI', 'CINF', 'USB', 'SBUX', 'RSG', 'GNRC', 'OTIS', 'EG', 'VZ', 'CDNS', 'ROP', 'BKNG', 'EIX', 'PM', 'TMUS', 'BSX', 'ERIE', 'VRSN', 'TFC', 'FTV', 'KEY', 'EMR', 'XYL', 'MAR', 'VRTX', 'DRI', 'LLY', 'COST', 'NOW', 'KO', 'NFLX', 'NEM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# 2025-10-29 17:04:55,078 - ERROR - No data returned for any tickers in S&P 500.
# 2025-10-29 17:04:55,080 - INFO - --- Scraping ticker list for Dow Jones ---
# 2025-10-29 17:04:55,571 - INFO - [SUCCESS] Fetched 30 tickers for Dow Jones. First 5: ['MMM', 'AXP', 'AMGN', 'AMZN', 'AAPL']
# 2025-10-29 17:04:55,572 - INFO - === Starting data fetch for Dow Jones (30 stocks) ===
# 2025-10-29 17:04:56,309 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:04:56,350 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*************         27%                       ]  8 of 30 completed2025-10-29 17:04:57,699 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****************      33%                       ]  10 of 30 completed2025-10-29 17:04:57,719 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********************* 43%                       ]  13 of 30 completed2025-10-29 17:04:59,551 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************47%                       ]  14 of 30 completed2025-10-29 17:04:59,586 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************73%**********             ]  22 of 30 completed2025-10-29 17:05:00,666 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************77%************           ]  23 of 30 completed2025-10-29 17:05:00,696 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********************100%***********************]  29 of 30 completed
# 2025-10-29 17:05:03,840 - ERROR -
# 30 Failed downloads:
# [*********************100%***********************]  29 of 30 completed2025-10-29 17:05:03,844 - ERROR - ['MSFT', 'AMGN', 'JPM', 'VZ', 'CVX', 'PG', 'MMM', 'V', 'CRM', 'BA', 'NKE', 'AXP', 'HD', 'DIS', 'MCD', 'IBM', 'HON', 'MRK', 'AMZN', 'CSCO', 'NVDA', 'AAPL', 'UNH', 'JNJ', 'TRV', 'SHW', 'GS', 'WMT', 'KO', 'CAT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# 2025-10-29 17:05:03,850 - ERROR - No data returned for any tickers in Dow Jones.
# 2025-10-29 17:05:03,851 - INFO - --- Scraping ticker list for NASDAQ 100 ---
# 2025-10-29 17:05:04,181 - INFO - [SUCCESS] Fetched 101 tickers for NASDAQ 100. First 5: ['ADBE', 'AMD', 'ABNB', 'GOOGL', 'GOOG']
# 2025-10-29 17:05:04,183 - INFO - === Starting data fetch for NASDAQ 100 (101 stocks) ===
# 2025-10-29 17:05:04,921 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:04,944 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****                   9%                       ]  9 of 101 completed2025-10-29 17:05:06,377 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*****                 10%                       ]  10 of 101 completed2025-10-29 17:05:06,516 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******                13%                       ]  13 of 101 completed2025-10-29 17:05:07,992 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******               15%                       ]  15 of 101 completed2025-10-29 17:05:08,027 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***********           22%                       ]  22 of 101 completed2025-10-29 17:05:09,397 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:09,401 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*************         27%                       ]  27 of 101 completed2025-10-29 17:05:11,300 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:11,324 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****************      34%                       ]  34 of 101 completed2025-10-29 17:05:12,573 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:12,628 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******************    38%                       ]  38 of 101 completed2025-10-29 17:05:14,201 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******************   39%                       ]  39 of 101 completed2025-10-29 17:05:14,225 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************46%                       ]  46 of 101 completed2025-10-29 17:05:16,161 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:16,175 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************50%                       ]  51 of 101 completed2025-10-29 17:05:17,261 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:17,266 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************56%**                     ]  57 of 101 completed2025-10-29 17:05:18,549 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************57%**                     ]  58 of 101 completed2025-10-29 17:05:18,585 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************63%*****                  ]  64 of 101 completed2025-10-29 17:05:20,143 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:20,150 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************68%********               ]  69 of 101 completed2025-10-29 17:05:21,255 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************69%********               ]  70 of 101 completed2025-10-29 17:05:21,261 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************75%***********            ]  76 of 101 completed2025-10-29 17:05:22,723 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:22,728 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************80%*************          ]  81 of 101 completed2025-10-29 17:05:23,979 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************81%**************         ]  82 of 101 completed2025-10-29 17:05:24,007 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************87%*****************      ]  88 of 101 completed2025-10-29 17:05:25,139 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:25,164 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************91%*******************    ]  92 of 101 completed2025-10-29 17:05:26,872 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************93%********************   ]  94 of 101 completed2025-10-29 17:05:26,875 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********************100%***********************]  101 of 101 completed
# 2025-10-29 17:05:27,912 - ERROR -
# 101 Failed downloads:
# 2025-10-29 17:05:27,913 - ERROR - ['EXC', 'PCAR', 'REGN', 'MSFT', 'LIN', 'GOOGL', 'BIIB', 'MCHP', 'IDXX', 'FTNT', 'KDP', 'FAST', 'MNST', 'CMCSA', 'CSCO', 'FANG', 'PLTR', 'LRCX', 'ISRG', 'DASH', 'GILD', 'AVGO', 'CTSH', 'MELI', 'CSX', 'GOOG', 'VRSK', 'LULU', 'CHTR', 'TSLA', 'INTC', 'ASML', 'AXON', 'CRWD', 'AEP', 'KHC', 'XEL', 'WBD', 'ORLY', 'INTU', 'GFS', 'KLAC', 'PDD', 'TEAM', 'PAYX', 'ARM', 'AZN', 'CEG', 'ODFL', 'PANW', 'CCEP', 'ON', 'DXCM', 'WDAY', 'NXPI', 'QCOM', 'PYPL', 'NVDA', 'HON', 'META', 'AMD', 'ADSK', 'AMZN', 'SHOP', 'SBUX', 'ADP', 'CDNS', 'TTWO', 'ADBE', 'AMGN', 'MDLZ', 'ROP', 'TTD', 'EA', 'ADI', 'CTAS', 'BKR', 'TMUS', 'MSTR', 'AMAT', 'GEHC', 'BKNG', 'CSGP', 'PEP', 'SNPS', 'CPRT', 'ROST', 'MRVL', 'TRI', 'AAPL', 'CDW', 'DDOG', 'MAR', 'VRTX', 'ABNB', 'ZS', 'TXN', 'MU', 'COST', 'APP', 'NFLX']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# 2025-10-29 17:05:27,922 - ERROR - No data returned for any tickers in NASDAQ 100.
# 2025-10-29 17:05:27,923 - INFO - --- Scraping ticker list for Nifty 50 ---
# 2025-10-29 17:05:28,291 - INFO - [SUCCESS] Fetched 50 tickers for Nifty 50. First 5: ['ADANIENT.NS', 'ADANIPORTS.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS', 'AXISBANK.NS']
# 2025-10-29 17:05:28,292 - INFO - === Starting data fetch for Nifty 50 (50 stocks) ===
# 2025-10-29 17:05:28,556 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:28,599 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********             18%                       ]  9 of 50 completed2025-10-29 17:05:30,758 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********            20%                       ]  10 of 50 completed2025-10-29 17:05:30,853 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [************          24%                       ]  12 of 50 completed2025-10-29 17:05:32,210 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:32,233 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*******************   40%                       ]  20 of 50 completed2025-10-29 17:05:33,413 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********************  42%                       ]  21 of 50 completed2025-10-29 17:05:33,471 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************50%                       ]  25 of 50 completed2025-10-29 17:05:35,395 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:35,456 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************66%*******                ]  33 of 50 completed2025-10-29 17:05:36,582 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************68%********               ]  34 of 50 completed2025-10-29 17:05:36,616 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************74%***********            ]  37 of 50 completed2025-10-29 17:05:37,912 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:37,919 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************88%*****************      ]  44 of 50 completed2025-10-29 17:05:39,399 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************90%******************     ]  45 of 50 completed2025-10-29 17:05:39,429 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********************100%***********************]  50 of 50 completed
# 2025-10-29 17:05:40,983 - ERROR -
# 50 Failed downloads:
# 2025-10-29 17:05:40,984 - ERROR - ['INDIGO.NS', 'M&M.NS', 'ADANIPORTS.NS', 'APOLLOHOSP.NS', 'ONGC.NS', 'HDFCLIFE.NS', 'GRASIM.NS', 'HINDALCO.NS', 'INFY.NS', 'BAJAJFINSV.NS', 'BEL.NS', 'DRREDDY.NS', 'ICICIBANK.NS', 'SHRIRAMFIN.NS', 'WIPRO.NS', 'EICHERMOT.NS', 'RELIANCE.NS', 'NESTLEIND.NS', 'COALINDIA.NS', 'MAXHEALTH.NS', 'NTPC.NS', 'JIOFIN.NS', 'SBIN.NS', 'ADANIENT.NS', 'ASIANPAINT.NS', 'BAJAJ-AUTO.NS', 'MARUTI.NS', 'CIPLA.NS', 'POWERGRID.NS', 'BAJFINANCE.NS', 'JSWSTEEL.NS', 'HINDUNILVR.NS', 'TECHM.NS', 'TCS.NS', 'KOTAKBANK.NS', 'TATACONSUM.NS', 'SUNPHARMA.NS', 'ITC.NS', 'ULTRACEMCO.NS', 'SBILIFE.NS', 'TRENT.NS', 'TATASTEEL.NS', 'HCLTECH.NS', 'ETERNAL.NS', 'HDFCBANK.NS', 'TATAMOTORS.NS', 'TITAN.NS', 'AXISBANK.NS', 'LT.NS', 'BHARTIARTL.NS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# 2025-10-29 17:05:40,989 - ERROR - No data returned for any tickers in Nifty 50.
# 2025-10-29 17:05:40,990 - INFO - --- Scraping ticker list for FTSE 100 ---
# 2025-10-29 17:05:41,346 - INFO - [SUCCESS] Fetched 100 tickers for FTSE 100. First 5: ['III.L', 'ADM.L', 'AAF.L', 'ALW.L', 'AAL.L']
# 2025-10-29 17:05:41,347 - INFO - === Starting data fetch for FTSE 100 (100 stocks) ===
# 2025-10-29 17:05:41,544 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:41,557 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*****                 10%                       ]  10 of 100 completed2025-10-29 17:05:43,355 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:43,360 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********              17%                       ]  17 of 100 completed2025-10-29 17:05:44,874 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********             18%                       ]  18 of 100 completed2025-10-29 17:05:44,996 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [************          25%                       ]  25 of 100 completed2025-10-29 17:05:46,425 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:46,517 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [***************       32%                       ]  32 of 100 completed2025-10-29 17:05:48,213 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [****************      33%                       ]  33 of 100 completed2025-10-29 17:05:48,273 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [******************    37%                       ]  37 of 100 completed2025-10-29 17:05:49,605 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:49,634 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [********************* 44%                       ]  44 of 100 completed2025-10-29 17:05:51,236 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************45%                       ]  45 of 100 completed2025-10-29 17:05:51,268 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************49%                       ]  49 of 100 completed2025-10-29 17:05:53,013 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:53,034 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************57%**                     ]  57 of 100 completed2025-10-29 17:05:54,197 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************58%***                    ]  58 of 100 completed2025-10-29 17:05:54,204 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************61%****                   ]  61 of 100 completed2025-10-29 17:05:55,916 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:55,919 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************69%********               ]  69 of 100 completed2025-10-29 17:05:57,741 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************70%*********              ]  70 of 100 completed2025-10-29 17:05:57,797 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************73%**********             ]  73 of 100 completed2025-10-29 17:05:59,029 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:05:59,109 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************81%**************         ]  81 of 100 completed2025-10-29 17:06:00,349 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:06:00,352 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************87%*****************      ]  87 of 100 completed2025-10-29 17:06:01,505 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# 2025-10-29 17:06:01,514 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************96%*********************  ]  96 of 100 completed2025-10-29 17:06:03,265 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [**********************97%********************** ]  97 of 100 completed2025-10-29 17:06:03,555 - WARNING - Connection pool is full, discarding connection: query2.finance.yahoo.com. Connection pool size: 10
# [*********************100%***********************]  100 of 100 completed
# 2025-10-29 17:06:04,739 - ERROR -
# 100 Failed downloads:
# 2025-10-29 17:06:04,740 - ERROR - ['SMT.L', 'BT-A.L', 'KGF.L', 'DPLM.L', 'CPG.L', 'BP.L', 'GLEN.L', 'IMB.L', 'BRBY.L', 'PHNX.L', 'DGE.L', 'HSBA.L', 'AUTO.L', 'BARC.L', 'PSH.L', 'BATS.L', 'III.L', 'WTB.L', 'HIK.L', 'GSK.L', 'ANTO.L', 'MNG.L', 'SDR.L', 'BNZL.L', 'IMI.L', 'CRDA.L', 'SGE.L', 'NXT.L', 'VOD.L', 'ADM.L', 'PSN.L', 'BAB.L', 'MTLN.L', 'WPP.L', 'MKS.L', 'HLN.L', 'MRO.L', 'AZN.L', 'GAW.L', 'HSX.L', 'CCH.L', 'EXPN.L', 'SHEL.L', 'RMV.L', 'RIO.L', 'STJ.L', 'LMP.L', 'LGEN.L', 'SPX.L', 'CTEC.L', 'CNA.L', 'ENT.L', 'NG.L', 'RTO.L', 'IHG.L', 'WEIR.L', 'NWG.L', 'EZJ.L', 'PSON.L', 'SSE.L', 'BA.L', 'ABF.L', 'BKG.L', 'FCIT.L', 'AHT.L', 'SGRO.L', 'REL.L', 'BTRW.L', 'LAND.L', 'RR.L', 'BEZ.L', 'FRES.L', 'HWDN.L', 'STAN.L', 'AAF.L', 'IAG.L', 'SN.L', 'JD.L', 'CCEP.L', 'INF.L', 'EDV.L', 'LSEG.L', 'ITRK.L', 'ICG.L', 'LLOY.L', 'RKT.L', 'UU.L', 'HLMA.L', 'ALW.L', 'DCC.L', 'MNDI.L', 'PRU.L', 'SMIN.L', 'AV.L', 'AAL.L', 'SBRY.L', 'ULVR.L', 'PCT.L', 'TSCO.L', 'SVT.L']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# 2025-10-29 17:06:04,764 - ERROR - No data returned for any tickers in FTSE 100.
# 2025-10-29 17:06:04,767 - INFO - === ALL PROCESSES COMPLETE ===

# %%
# !pip install dash_bootstrap_components

# %%
import pandas as pd
from dash import Dash, html, dcc, Input, Output
import plotly.graph_objs as go
import dash_bootstrap_components as dbc

# ---------- CONFIG: Define file paths ----------
file_paths = {
    "Dow Jones": r"C:\Users\prabh\DA2402\Dow_Jones_stock_data.csv",
    "NASDAQ 100": r"C:\Users\prabh\DA2402\NASDAQ_100_stock_data.csv",
    "S&P 500": r"C:\Users\prabh\DA2402\S&P_500_stock_data.csv",
    "FTSE 100": r"C:\Users\prabh\DA2402\FTSE_100_stock_data.csv",
    "Nifty 50": r"C:\Users\prabh\DA2402\Nifty_50_stock_data.csv",
}

# ---------- Data Processing ----------
def compute_pct_changes(df: pd.DataFrame, date_col: str = 'Date'):
    df = df.copy()
    df[date_col] = pd.to_datetime(df[date_col])
    df.sort_values(date_col, inplace=True)
    stock_names = [col.replace('Close', '') for col in df.columns if col.endswith('Close')]
    result = {}
    last_date = df[date_col].iloc[-1]
    lookup = df.set_index(date_col)

    def get_prev(date, days):
        target = date - pd.Timedelta(days=days)
        prev = lookup[lookup.index <= target]
        return prev.iloc[-1] if not prev.empty else lookup.iloc[0]

    for stock in stock_names:
        if f'{stock}Close' not in lookup.columns or pd.isna(lookup[f'{stock}Close'].iloc[-1]):
            continue

        last_close = lookup[f'{stock}Close'].iloc[-1]
        last_volume = lookup[f'{stock}Volume'].iloc[-1]
        prev_day_row = lookup.iloc[-2] if len(lookup) > 1 else lookup.iloc[0]
        prev_week_row = get_prev(last_date, 7)
        prev_month_row = get_prev(last_date, 30)
        prev_year_row = get_prev(last_date, 365)

        def pct_change(now, prev): return 100 * (now - prev) / prev if prev != 0 else 0

        result[stock] = {
            'last_close': last_close,
            'last_day_pct': pct_change(last_close, prev_day_row[f'{stock}Close']),
            'last_day_volume': abs(last_volume - prev_day_row[f'{stock}Volume']),
            'last_week_pct': pct_change(last_close, prev_week_row[f'{stock}Close']),
            'last_week_volume': abs(last_volume - prev_week_row[f'{stock}Volume']),
            'last_month_pct': pct_change(last_close, prev_month_row[f'{stock}Close']),
            'last_month_volume': abs(last_volume - prev_month_row[f'{stock}Volume']),
            'last_year_pct': pct_change(last_close, prev_year_row[f'{stock}Close']),
            'last_year_volume': abs(last_volume - prev_year_row[f'{stock}Volume']),
        }
    return result

# ---------- Load All Datasets ----------
index_data = {}
for name, path in file_paths.items():
    try:
        df = pd.read_csv(path)
        index_data[name] = compute_pct_changes(df)
    except FileNotFoundError:
        print(f"⚠ File not found: {path}")
        index_data[name] = {}

# ---------- Visualization Helpers ----------
def get_top_bottom(data, period, top_n=5):
    valid_data = {k: v for k, v in data.items() if pd.notna(v.get(period))}
    sorted_stocks = sorted(valid_data.items(), key=lambda x: x[1][period])
    losers = sorted_stocks[:top_n]
    gainers = sorted_stocks[-top_n:]
    return sorted(losers + gainers, key=lambda x: x[1][period])

def create_symmetrical_bar(period, data, title):
    if not data:
        return go.Figure().update_layout(title="No data available", paper_bgcolor='black', font=dict(color='white'))

    top_bottom_stocks = get_top_bottom(data, period)
    stock_names = [s[0].strip('_') for s in top_bottom_stocks]
    pct_changes = [s[1][period] for s in top_bottom_stocks]
    colors = ['#d62728' if pct < 0 else '#2ca02c' for pct in pct_changes]
    closes = [s[1]['last_close'] for s in top_bottom_stocks]
    volumes = [s[1].get(period.replace('_pct', '_volume'), 0) for s in top_bottom_stocks]

    hover_texts = [
        f"<b>{name}</b><br>"
        f"Change: {pct:.2f}%<br>"
        f"Close: {close:,.2f}<br>"
        f"Volume Δ: {int(vol):,}<extra></extra>"
        for name, pct, close, vol in zip(stock_names, pct_changes, closes, volumes)
    ]

    text_labels = [f'{pct:.2f}%' for pct in pct_changes]

    fig = go.Figure(go.Bar(
        x=pct_changes,
        y=stock_names,
        orientation='h',
        marker=dict(color=colors, line=dict(color='white', width=1)),
        text=text_labels,
        textposition='outside',
        textfont=dict(size=12, color='white'),
        hoverinfo='text',
        hovertext=hover_texts
    ))

    max_abs_change = max(abs(p) for p in pct_changes)
    axis_limit = max_abs_change * 1.25

    fig.update_layout(
        title=dict(text=title, x=0.5, font=dict(size=22, family='Arial Black')),
        xaxis=dict(
            title='Percentage Change (%)',
            range=[-axis_limit, axis_limit],
            showgrid=True,
            gridcolor='rgba(255,255,255,0.1)',
            zeroline=True,
            zerolinecolor='rgba(255,255,255,0.5)',
            zerolinewidth=2
        ),
        yaxis=dict(title='Stock', tickfont=dict(size=12)),
        plot_bgcolor='rgba(0,0,0,0)',
        paper_bgcolor='rgba(0,0,0,0)',
        font=dict(color='white'),
        height=600,
        margin=dict(l=120, r=60, t=80, b=60),
        showlegend=False
    )
    return fig

# ---------- App Layout ----------
app = Dash(__name__, external_stylesheets=[dbc.themes.SLATE])

tabs_config = [
    {'label': 'Last Day', 'value': 'tab-day', 'period': 'last_day_pct', 'title': 'Top 5 Gainers & Losers - Daily'},
    {'label': 'Last Week', 'value': 'tab-week', 'period': 'last_week_pct', 'title': 'Top 5 Gainers & Losers - Weekly'},
    {'label': 'Last Month', 'value': 'tab-month', 'period': 'last_month_pct', 'title': 'Top 5 Gainers & Losers - Monthly'},
    {'label': 'Last Year', 'value': 'tab-year', 'period': 'last_year_pct', 'title': 'Top 5 Gainers & Losers - Yearly'},
]

app.layout = dbc.Container([
    html.Br(),
    html.H1("🌍 Global Market Performance Dashboard",
            className="text-center text-info mb-4",
            style={'fontFamily': 'Trebuchet MS', 'fontWeight': 'bold'}),

    # Dropdown for index selection
    dbc.Row([
        dbc.Col([
            html.Label("Select Stock Index:", style={'color': '#00FFFF', 'fontSize': '18px'}),
            dcc.Dropdown(
                id='index-selector',
                options=[{'label': name, 'value': name} for name in index_data.keys()],
                value='Dow Jones',
                clearable=False,
                style={'backgroundColor': '#222', 'color': 'black'}
            )
        ], width=6)
    ], className="mb-4 justify-content-center"),

    # Top Gainer / Loser cards
    dbc.Row([
        dbc.Col(dbc.Card([
            dbc.CardBody([
                html.H5("Top Gainer", className="card-title text-success"),
                html.H3(id='top-gainer-name'),
                html.P(id='top-gainer-value', className="text-success"),
                html.P(id='top-gainer-close', className="text-light mb-0"),
                html.P(id='top-gainer-vol', className="text-info mb-0")
            ])
        ], color="dark", outline=True, style={'borderRadius': '12px', 'boxShadow': '0 0 10px #00ff99'})),

        dbc.Col(dbc.Card([
            dbc.CardBody([
                html.H5("Top Loser", className="card-title text-danger"),
                html.H3(id='top-loser-name'),
                html.P(id='top-loser-value', className="text-danger"),
                html.P(id='top-loser-close', className="text-light mb-0"),
                html.P(id='top-loser-vol', className="text-info mb-0")
            ])
        ], color="dark", outline=True, style={'borderRadius': '12px', 'boxShadow': '0 0 10px #ff4d4d'}))
    ], className="mb-4"),

    # Tabs for time periods
    dcc.Tabs(id='performance-tabs', value='tab-day', children=[
        dcc.Tab(label=t['label'], value=t['value'],
                style={'padding': '12px', 'backgroundColor': '#222'},
                selected_style={'padding': '12px', 'fontWeight': 'bold', 'borderBottom': '3px solid #00FFFF'})
        for t in tabs_config
    ]),
    
    # Visualization container
    html.Div(id='tab-content', style={'backgroundColor': '#212529', 'padding': '20px', 'borderRadius': '15px'})
], fluid=True)

# ---------- Callback ----------
@app.callback(
    [Output('tab-content', 'children'),
     Output('top-gainer-name', 'children'),
     Output('top-gainer-value', 'children'),
     Output('top-gainer-close', 'children'),
     Output('top-gainer-vol', 'children'),
     Output('top-loser-name', 'children'),
     Output('top-loser-value', 'children'),
     Output('top-loser-close', 'children'),
     Output('top-loser-vol', 'children')],
    [Input('index-selector', 'value'),
     Input('performance-tabs', 'value')]
)
def update_dashboard(selected_index, tab_value):
    change_dict = index_data.get(selected_index, {})
    config = next(t for t in tabs_config if t['value'] == tab_value)
    period = config['period']
    title = f"{selected_index} — {config['title']}"

    fig = create_symmetrical_bar(period, change_dict, title)
    graph = dcc.Graph(figure=fig, style={'height': '650px'})

    if not change_dict:
        return graph, "-", "-", "-", "-", "-", "-", "-", "-"

    valid_data = {k: v for k, v in change_dict.items() if pd.notna(v.get(period))}
    if not valid_data:
        return graph, "-", "-", "-", "-", "-", "-", "-", "-"

    top_gainer = max(valid_data.items(), key=lambda x: x[1][period])
    top_loser = min(valid_data.items(), key=lambda x: x[1][period])

    g_name = top_gainer[0].strip('_')
    g_val = f"+{top_gainer[1][period]:.2f}%"
    g_close = f"Close: {top_gainer[1]['last_close']:,.2f}"
    g_vol = f"Volume Δ: {int(top_gainer[1][period.replace('_pct', '_volume')]):,}"

    l_name = top_loser[0].strip('_')
    l_val = f"{top_loser[1][period]:.2f}%"
    l_close = f"Close: {top_loser[1]['last_close']:,.2f}"
    l_vol = f"Volume Δ: {int(top_loser[1][period.replace('_pct', '_volume')]):,}"

    return graph, g_name, g_val, g_close, g_vol, l_name, l_val, l_close, l_vol


if __name__ == '__main__':
    app.run(debug=True)
